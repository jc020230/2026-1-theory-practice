# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Third Edition](https://www.manning.com/books/deep-learning-with-python-third-edition). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# The book's contents are available online at [deeplearningwithpython.io](https://deeplearningwithpython.io).

# %%
# !pip install keras keras-hub --upgrade -q

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %% [markdown]
# ## Image classification

# %% [markdown]
# ### Introduction to ConvNets

# %%
import keras
from keras import layers

inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary(line_length=80)
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)        │ (None, 28, 28, 1)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)                 │ (None, 26, 26, 64)       │           640 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)    │ (None, 13, 13, 64)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)                 │ (None, 11, 11, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)    │ (None, 5, 5, 128)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)                 │ (None, 3, 3, 256)        │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d_2        │ (None, 256)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_2 (Dense)                   │ (None, 10)               │         2,570 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 372,234 (1.42 MB)
#  Trainable params: 372,234 (1.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9194 - loss: 0.2564
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9781 - loss: 0.0726
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9853 - loss: 0.0475
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9891 - loss: 0.0345
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9914 - loss: 0.0278

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9898 - loss: 0.0327
# Test accuracy: 0.990

# %% [markdown]
# #### The convolution operation

# %% [markdown]
# ##### Understanding border effects and padding

# %% [markdown]
# ##### Understanding convolution strides

# %% [markdown]
# #### The max-pooling operation

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary(line_length=80)
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)        │ (None, 28, 28, 1)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)                 │ (None, 26, 26, 64)       │           640 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)                │ (None, 24, 24, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)                │ (None, 22, 22, 256)      │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d_3        │ (None, 256)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_3 (Dense)                   │ (None, 10)               │         2,570 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 372,234 (1.42 MB)
#  Trainable params: 372,234 (1.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training a ConvNet from scratch on a small dataset

# %% [markdown]
# #### The relevance of deep learning for small-data problems

# %% [markdown]
# #### Downloading the data

# %% [markdown]
# !unzip -qq dogs-vs-cats.zip
# !unzip -qq train.zip

# %%
import kagglehub

kagglehub.login()

# %%
download_path = kagglehub.competition_download("dogs-vs-cats")

# %%
import zipfile
import os

# First, extract the main competition zip file
# download_path points to '/content/dogs-vs-cats.zip'
with zipfile.ZipFile(download_path, "r") as zip_ref:
    # Extract its contents to the /content/ directory
    # This should create 'train.zip' and 'test1.zip' inside /content/
    zip_ref.extractall("/content/")

# Now, locate train.zip and extract its contents
train_zip_path = "/content/train.zip"
if os.path.exists(train_zip_path):
    with zipfile.ZipFile(train_zip_path, "r") as zip_ref:
        # Extract the contents of train.zip to the current working directory (which will create a 'train' folder)
        zip_ref.extractall(".")
else:
    print(f"Error: {train_zip_path} not found after extracting {download_path}")

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("dogs_vs_cats_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir, exist_ok=True)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname, dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# #### Building your model

# %%
import keras
from keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1.0 / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary(line_length=80)
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)        │ (None, 180, 180, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ rescaling_1 (Rescaling)           │ (None, 180, 180, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)                │ (None, 178, 178, 32)     │           896 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)    │ (None, 89, 89, 32)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)                │ (None, 87, 87, 64)       │        18,496 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)    │ (None, 43, 43, 64)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)                │ (None, 41, 41, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D)   │ (None, 20, 20, 128)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)                │ (None, 18, 18, 256)      │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D)   │ (None, 9, 9, 256)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)                │ (None, 7, 7, 512)        │     1,180,160 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d_5        │ (None, 512)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_5 (Dense)                   │ (None, 1)                │           513 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 1,569,089 (5.99 MB)
#  Trainable params: 1,569,089 (5.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %% [markdown]
# #### Data preprocessing

# %%
from keras.utils import image_dataset_from_directory

batch_size = 64
image_size = (180, 180)
train_dataset = image_dataset_from_directory(
    new_base_dir / "train", image_size=image_size, batch_size=batch_size
)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation", image_size=image_size, batch_size=batch_size
)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test", image_size=image_size, batch_size=batch_size
)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %% [markdown]
# ##### Understanding TensorFlow Dataset objects

# %%
import numpy as np
import tensorflow as tf

random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(
    lambda x: tf.reshape(x, (4, 4)),
    num_parallel_calls=8)
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# ##### Fitting the model

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (64, 180, 180, 3)
# labels batch shape: (64,)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 400ms/step - accuracy: 0.5130 - loss: 0.6994 - val_accuracy: 0.5080 - val_loss: 0.6929
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.5065 - loss: 0.6921 - val_accuracy: 0.5080 - val_loss: 0.6915
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 0.5270 - loss: 0.6894 - val_accuracy: 0.5850 - val_loss: 0.6868
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.5840 - loss: 0.6739 - val_accuracy: 0.6330 - val_loss: 0.6493
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.6210 - loss: 0.6538 - val_accuracy: 0.5910 - val_loss: 0.6610
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - accuracy: 0.6250 - loss: 0.6485 - val_accuracy: 0.5970 - val_loss: 0.6496
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.6380 - loss: 0.6479 - val_accuracy: 0.6380 - val_loss: 0.6287
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.6680 - loss: 0.6225 - val_accuracy: 0.6670 - val_loss: 0.6032
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step - accuracy: 0.6980 - loss: 0.5904 - val_accuracy: 0.6880 - val_loss: 0.6120
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.6950 - loss: 0.5822 - val_accuracy: 0.6960 - val_loss: 0.5850
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.7205 - loss: 0.5611 - val_accuracy: 0.7150 - val_loss: 0.5714
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - accuracy: 0.6845 - loss: 0.5849 - val_accuracy: 0.7180 - val_loss: 0.5661
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.7395 - loss: 0.5391 - val_accuracy: 0.7380 - val_loss: 0.5493
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.7435 - loss: 0.5176 - val_accuracy: 0.7290 - val_loss: 0.5521
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.7350 - loss: 0.5217 - val_accuracy: 0.7410 - val_loss: 0.5377
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.7535 - loss: 0.5069 - val_accuracy: 0.7430 - val_loss: 0.5381
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.7925 - loss: 0.4498 - val_accuracy: 0.7510 - val_loss: 0.5652
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.7555 - loss: 0.4993 - val_accuracy: 0.7550 - val_loss: 0.5181
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.8100 - loss: 0.4145 - val_accuracy: 0.7660 - val_loss: 0.5069
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - accuracy: 0.8190 - loss: 0.3928 - val_accuracy: 0.7750 - val_loss: 0.5049
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.8470 - loss: 0.3581 - val_accuracy: 0.7700 - val_loss: 0.4896
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.8585 - loss: 0.3369 - val_accuracy: 0.7600 - val_loss: 0.5637
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.8780 - loss: 0.2890 - val_accuracy: 0.6630 - val_loss: 0.9716
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8615 - loss: 0.3224 - val_accuracy: 0.7770 - val_loss: 0.5239
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.9015 - loss: 0.2334 - val_accuracy: 0.7340 - val_loss: 0.7356
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - accuracy: 0.9240 - loss: 0.2029 - val_accuracy: 0.7890 - val_loss: 0.5757
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.9145 - loss: 0.2045 - val_accuracy: 0.7940 - val_loss: 0.5708
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9245 - loss: 0.1891 - val_accuracy: 0.7680 - val_loss: 0.6469
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.9285 - loss: 0.1941 - val_accuracy: 0.8110 - val_loss: 0.5918
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - accuracy: 0.9625 - loss: 0.1042 - val_accuracy: 0.8080 - val_loss: 0.6164
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9635 - loss: 0.0985 - val_accuracy: 0.7900 - val_loss: 0.8900
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9805 - loss: 0.0687 - val_accuracy: 0.8090 - val_loss: 0.7124
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - accuracy: 0.9790 - loss: 0.0535 - val_accuracy: 0.8110 - val_loss: 0.7914
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.9865 - loss: 0.0434 - val_accuracy: 0.7950 - val_loss: 0.7642
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.9870 - loss: 0.0468 - val_accuracy: 0.8070 - val_loss: 0.8196
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.9900 - loss: 0.0334 - val_accuracy: 0.8160 - val_loss: 0.7930
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9975 - loss: 0.0186 - val_accuracy: 0.8040 - val_loss: 0.8559
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.9980 - loss: 0.0120 - val_accuracy: 0.8090 - val_loss: 0.9203
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.9985 - loss: 0.0102 - val_accuracy: 0.7990 - val_loss: 1.0786
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.9940 - loss: 0.0176 - val_accuracy: 0.8220 - val_loss: 0.8545
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9890 - loss: 0.0335 - val_accuracy: 0.7950 - val_loss: 0.9530
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step - accuracy: 0.8610 - loss: 0.3685 - val_accuracy: 0.7710 - val_loss: 0.5905
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.9580 - loss: 0.1180 - val_accuracy: 0.8030 - val_loss: 0.7740
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.9660 - loss: 0.0934 - val_accuracy: 0.8190 - val_loss: 0.6177
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9865 - loss: 0.0477 - val_accuracy: 0.7970 - val_loss: 0.8165
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.9940 - loss: 0.0244 - val_accuracy: 0.8180 - val_loss: 0.8242
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.9990 - loss: 0.0099 - val_accuracy: 0.8250 - val_loss: 0.8771
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.9990 - loss: 0.0055 - val_accuracy: 0.8170 - val_loss: 0.9131
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.9995 - loss: 0.0043 - val_accuracy: 0.8200 - val_loss: 0.9533
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.9995 - loss: 0.0031 - val_accuracy: 0.8130 - val_loss: 0.9744

# %%
import matplotlib.pyplot as plt

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)

plt.plot(epochs, accuracy, "r--", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()

plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.7940 - loss: 0.4926
# Test accuracy: 0.794

# %% [markdown]
# #### Using data augmentation

# %%
data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
]

def data_augmentation(images, targets):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images, targets

augmented_train_dataset = train_dataset.map(
    data_augmentation, num_parallel_calls=8
)
augmented_train_dataset = augmented_train_dataset.prefetch(tf.data.AUTOTUNE)

# %%
plt.figure(figsize=(10, 10))
for image_batch, _ in train_dataset.take(1):
    image = image_batch[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image, _ = data_augmentation(image, None)
        augmented_image = keras.ops.convert_to_numpy(augmented_image)
        plt.imshow(augmented_image.astype("uint8"))
        plt.axis("off")

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1.0 / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 394ms/step - accuracy: 0.5140 - loss: 0.6926 - val_accuracy: 0.5640 - val_loss: 0.6904
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 676ms/step - accuracy: 0.5055 - loss: 0.6939 - val_accuracy: 0.5000 - val_loss: 0.6916
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 427ms/step - accuracy: 0.5165 - loss: 0.6886 - val_accuracy: 0.6190 - val_loss: 0.6626
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 674ms/step - accuracy: 0.5675 - loss: 0.6804 - val_accuracy: 0.6410 - val_loss: 0.6715
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 397ms/step - accuracy: 0.6265 - loss: 0.6591 - val_accuracy: 0.6690 - val_loss: 0.6256
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 652ms/step - accuracy: 0.6270 - loss: 0.6518 - val_accuracy: 0.6640 - val_loss: 0.6329
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 474ms/step - accuracy: 0.6045 - loss: 0.6544 - val_accuracy: 0.6770 - val_loss: 0.6135
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 623ms/step - accuracy: 0.6465 - loss: 0.6325 - val_accuracy: 0.6130 - val_loss: 0.6354
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 692ms/step - accuracy: 0.6595 - loss: 0.6200 - val_accuracy: 0.7160 - val_loss: 0.5883
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 406ms/step - accuracy: 0.6660 - loss: 0.6000 - val_accuracy: 0.6830 - val_loss: 0.6063
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 408ms/step - accuracy: 0.6720 - loss: 0.6047 - val_accuracy: 0.7100 - val_loss: 0.5717
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 408ms/step - accuracy: 0.6640 - loss: 0.6169 - val_accuracy: 0.6850 - val_loss: 0.5916
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 675ms/step - accuracy: 0.6845 - loss: 0.5992 - val_accuracy: 0.6720 - val_loss: 0.6205
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 643ms/step - accuracy: 0.6800 - loss: 0.6024 - val_accuracy: 0.6000 - val_loss: 0.6926
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 409ms/step - accuracy: 0.6815 - loss: 0.5961 - val_accuracy: 0.7080 - val_loss: 0.5794
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 680ms/step - accuracy: 0.7015 - loss: 0.5867 - val_accuracy: 0.7170 - val_loss: 0.5626
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 657ms/step - accuracy: 0.6930 - loss: 0.5796 - val_accuracy: 0.6830 - val_loss: 0.5946
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 658ms/step - accuracy: 0.7230 - loss: 0.5588 - val_accuracy: 0.6560 - val_loss: 0.6686
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 380ms/step - accuracy: 0.6880 - loss: 0.5795 - val_accuracy: 0.7180 - val_loss: 0.5703
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 433ms/step - accuracy: 0.7105 - loss: 0.5591 - val_accuracy: 0.7230 - val_loss: 0.5737
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 650ms/step - accuracy: 0.7120 - loss: 0.5665 - val_accuracy: 0.7110 - val_loss: 0.5740
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 719ms/step - accuracy: 0.7360 - loss: 0.5406 - val_accuracy: 0.7360 - val_loss: 0.5418
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 675ms/step - accuracy: 0.7335 - loss: 0.5356 - val_accuracy: 0.7280 - val_loss: 0.5576
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 672ms/step - accuracy: 0.7265 - loss: 0.5440 - val_accuracy: 0.7130 - val_loss: 0.5868
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 652ms/step - accuracy: 0.7390 - loss: 0.5286 - val_accuracy: 0.7390 - val_loss: 0.5542
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 386ms/step - accuracy: 0.7215 - loss: 0.5411 - val_accuracy: 0.7590 - val_loss: 0.5242
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 421ms/step - accuracy: 0.7400 - loss: 0.5286 - val_accuracy: 0.7410 - val_loss: 0.5384
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 424ms/step - accuracy: 0.7355 - loss: 0.5286 - val_accuracy: 0.7500 - val_loss: 0.5171
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 429ms/step - accuracy: 0.7665 - loss: 0.4942 - val_accuracy: 0.7650 - val_loss: 0.5242
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 713ms/step - accuracy: 0.7685 - loss: 0.4875 - val_accuracy: 0.7490 - val_loss: 0.5501
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 671ms/step - accuracy: 0.7390 - loss: 0.5317 - val_accuracy: 0.7610 - val_loss: 0.4978
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 426ms/step - accuracy: 0.7570 - loss: 0.4879 - val_accuracy: 0.7710 - val_loss: 0.4880
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 648ms/step - accuracy: 0.7760 - loss: 0.4704 - val_accuracy: 0.7790 - val_loss: 0.4823
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 435ms/step - accuracy: 0.7950 - loss: 0.4410 - val_accuracy: 0.7570 - val_loss: 0.5342
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 679ms/step - accuracy: 0.7970 - loss: 0.4453 - val_accuracy: 0.7880 - val_loss: 0.4557
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 420ms/step - accuracy: 0.7835 - loss: 0.4545 - val_accuracy: 0.7710 - val_loss: 0.5077
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 426ms/step - accuracy: 0.7780 - loss: 0.4641 - val_accuracy: 0.8000 - val_loss: 0.4439
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 439ms/step - accuracy: 0.8100 - loss: 0.4179 - val_accuracy: 0.7960 - val_loss: 0.5205
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 431ms/step - accuracy: 0.8065 - loss: 0.4280 - val_accuracy: 0.7700 - val_loss: 0.5078
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 401ms/step - accuracy: 0.8120 - loss: 0.4202 - val_accuracy: 0.8140 - val_loss: 0.4172
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - accuracy: 0.8226 - loss: 0.4027
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6915/3154851398.py in <cell line: 0>()
#       6     )
#       7 ]
# ----> 8 history = model.fit(
#       9     augmented_train_dataset,
#      10     epochs=100,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/jax/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     509                             shuffle=False,
#     510                         )
# --> 511                     val_logs = self.evaluate(
#     512                         x=val_x,
#     513                         y=val_y,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/jax/trainer.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     616                     self._jax_state_synced = False
#     617
# --> 618                 logs, state = self.test_function(state, iterator)
#     619                 (
#     620                     trainable_variables,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/jax/trainer.py in iterator_step(state, iterator)
#     255
#     256             def iterator_step(state, iterator):
# --> 257                 return step_function(state, next(iterator))
#     258
#     259         return iterator_step
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/jax/trainer.py in _one_batch_ahead_iterator(self, numpy_iterator)
#    1115         """
#    1116         next_batch = None
# -> 1117         for batch in numpy_iterator:
#    1118             batch = _distribute_data(batch)
#    1119             if next_batch is None:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/tf_dataset_adapter.py in get_jax_iterator(self)
#      54                 return convert_to_numpy(x)
#      55
# ---> 56         for batch in self._dataset:
#      57             yield tree.map_structure(convert_to_jax, batch, none_is_leaf=False)
#      58
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __next__(self)
#     824   def __next__(self):
#     825     try:
# --> 826       return self._next_internal()
#     827     except errors.OutOfRangeError:
#     828       raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _next_internal(self)
#     774     # to communicate that there is no more data to iterate over.
#     775     with context.execution_mode(context.SYNC):
# --> 776       ret = gen_dataset_ops.iterator_get_next(
#     777           self._iterator_resource,
#     778           output_types=self._flat_output_types,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in iterator_get_next(iterator, output_types, output_shapes, name)
#    3079   if tld.is_eager:
#    3080     try:
# -> 3081       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3082         _ctx, "IteratorGetNext", name, iterator, "output_types", output_types,
#    3083         "output_shapes", output_shapes)
#
# KeyboardInterrupt:

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras"
)
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")

# %% [markdown]
# ### Using a pretrained model

# %% [markdown]
# #### Feature extraction with a pretrained model

# %%
import keras_hub

conv_base = keras_hub.models.Backbone.from_preset("xception_41_imagenet")

# %%
preprocessor = keras_hub.layers.ImageConverter.from_preset(
    "xception_41_imagenet",
    image_size=(180, 180),
)

# %% [markdown]
# ##### Fast feature extraction without data augmentation

# %%
def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = preprocessor(images)
        features = conv_base.predict(preprocessed_images, verbose=0)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels = get_features_and_labels(train_dataset)
val_features, val_labels = get_features_and_labels(validation_dataset)
test_features, test_labels = get_features_and_labels(test_dataset)

# %%
train_features.shape
# Out:
# (2000, 6, 6, 2048)

# %%
inputs = keras.Input(shape=(6, 6, 2048))
x = layers.GlobalAveragePooling2D()(inputs)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    train_features,
    train_labels,
    epochs=10,
    validation_data=(val_features, val_labels),
    callbacks=callbacks,
)
# Out:
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.9695 - loss: 0.0860 - val_accuracy: 0.9860 - val_loss: 0.0465
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9845 - loss: 0.0328 - val_accuracy: 0.9850 - val_loss: 0.0500
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9920 - loss: 0.0188 - val_accuracy: 0.9840 - val_loss: 0.0478
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9990 - loss: 0.0060 - val_accuracy: 0.9870 - val_loss: 0.0486
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9850 - val_loss: 0.0613
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9995 - loss: 0.0024 - val_accuracy: 0.9850 - val_loss: 0.0578
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9990 - loss: 0.0038 - val_accuracy: 0.9850 - val_loss: 0.0628
# Epoch 8/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9820 - val_loss: 0.0695
# Epoch 9/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 7.8861e-04 - val_accuracy: 0.9820 - val_loss: 0.0715
# Epoch 10/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 5.4453e-04 - val_accuracy: 0.9830 - val_loss: 0.0656

# %%
import matplotlib.pyplot as plt

acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_features, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9825 - loss: 0.0515
# Test accuracy: 0.983

# %% [markdown]
# ##### Feature extraction together with data augmentation

# %%
import keras_hub

conv_base = keras_hub.models.Backbone.from_preset(
    "xception_41_imagenet",
    trainable=False,
)

# %%
conv_base.trainable = True
len(conv_base.trainable_weights)
# Out:
# 154

# %%
conv_base.trainable = False
len(conv_base.trainable_weights)
# Out:
# 0

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = preprocessor(inputs)
x = conv_base(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.9095 - loss: 0.2321 - val_accuracy: 0.9880 - val_loss: 0.0487
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 474ms/step - accuracy: 0.9640 - loss: 0.1157 - val_accuracy: 0.9780 - val_loss: 0.0653
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 548ms/step - accuracy: 0.9700 - loss: 0.0854 - val_accuracy: 0.9870 - val_loss: 0.0413
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 734ms/step - accuracy: 0.9740 - loss: 0.0719 - val_accuracy: 0.9870 - val_loss: 0.0444
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 741ms/step - accuracy: 0.9715 - loss: 0.0681 - val_accuracy: 0.9810 - val_loss: 0.0621
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 506ms/step - accuracy: 0.9645 - loss: 0.1127 - val_accuracy: 0.9850 - val_loss: 0.0567
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 741ms/step - accuracy: 0.9805 - loss: 0.0627 - val_accuracy: 0.9830 - val_loss: 0.0640
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 498ms/step - accuracy: 0.9700 - loss: 0.0880 - val_accuracy: 0.9840 - val_loss: 0.0527
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 714ms/step - accuracy: 0.9725 - loss: 0.0829 - val_accuracy: 0.9870 - val_loss: 0.0483
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 515ms/step - accuracy: 0.9770 - loss: 0.0666 - val_accuracy: 0.9830 - val_loss: 0.0608
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 469ms/step - accuracy: 0.9770 - loss: 0.0606 - val_accuracy: 0.9870 - val_loss: 0.0479
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 722ms/step - accuracy: 0.9840 - loss: 0.0386 - val_accuracy: 0.9880 - val_loss: 0.0455
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 744ms/step - accuracy: 0.9895 - loss: 0.0335 - val_accuracy: 0.9840 - val_loss: 0.0432
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 719ms/step - accuracy: 0.9825 - loss: 0.0411 - val_accuracy: 0.9870 - val_loss: 0.0422
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 727ms/step - accuracy: 0.9835 - loss: 0.0510 - val_accuracy: 0.9830 - val_loss: 0.0557
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 734ms/step - accuracy: 0.9870 - loss: 0.0310 - val_accuracy: 0.9850 - val_loss: 0.0492
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 521ms/step - accuracy: 0.9805 - loss: 0.0533 - val_accuracy: 0.9850 - val_loss: 0.0567
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 501ms/step - accuracy: 0.9775 - loss: 0.0620 - val_accuracy: 0.9890 - val_loss: 0.0477
# Epoch 19/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 514ms/step - accuracy: 0.9845 - loss: 0.0372 - val_accuracy: 0.9870 - val_loss: 0.0436
# Epoch 20/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 732ms/step - accuracy: 0.9870 - loss: 0.0377 - val_accuracy: 0.9830 - val_loss: 0.0520
# Epoch 21/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 709ms/step - accuracy: 0.9885 - loss: 0.0271 - val_accuracy: 0.9890 - val_loss: 0.0435
# Epoch 22/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 488ms/step - accuracy: 0.9830 - loss: 0.0492 - val_accuracy: 0.9810 - val_loss: 0.0548
# Epoch 23/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 486ms/step - accuracy: 0.9890 - loss: 0.0300 - val_accuracy: 0.9870 - val_loss: 0.0484
# Epoch 24/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 717ms/step - accuracy: 0.9825 - loss: 0.0442 - val_accuracy: 0.9900 - val_loss: 0.0419
# Epoch 25/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 464ms/step - accuracy: 0.9860 - loss: 0.0391 - val_accuracy: 0.9890 - val_loss: 0.0471
# Epoch 26/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 713ms/step - accuracy: 0.9875 - loss: 0.0375 - val_accuracy: 0.9830 - val_loss: 0.0529
# Epoch 27/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 505ms/step - accuracy: 0.9855 - loss: 0.0399 - val_accuracy: 0.9790 - val_loss: 0.0706
# Epoch 28/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 710ms/step - accuracy: 0.9870 - loss: 0.0364 - val_accuracy: 0.9840 - val_loss: 0.0518
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 727ms/step - accuracy: 0.9865 - loss: 0.0317 - val_accuracy: 0.9850 - val_loss: 0.0494
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 468ms/step - accuracy: 0.9855 - loss: 0.0352 - val_accuracy: 0.9850 - val_loss: 0.0605

# %%
test_model = keras.models.load_model(
    "feature_extraction_with_data_augmentation.keras"
)
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:801: UserWarning: Skipping variable loading for optimizer 'adam', because it has 318 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 305ms/step - accuracy: 0.9795 - loss: 0.0673
# Test accuracy: 0.980

# %% [markdown]
# #### Fine-tuning a pretrained model

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-5),
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 34s 809ms/step - accuracy: 0.9880 - loss: 0.0388 - val_accuracy: 0.9860 - val_loss: 0.0585
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 524ms/step - accuracy: 0.9890 - loss: 0.0317 - val_accuracy: 0.9830 - val_loss: 0.0575
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 738ms/step - accuracy: 0.9915 - loss: 0.0201 - val_accuracy: 0.9820 - val_loss: 0.0577
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 508ms/step - accuracy: 0.9915 - loss: 0.0238 - val_accuracy: 0.9820 - val_loss: 0.0576
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 755ms/step - accuracy: 0.9940 - loss: 0.0172 - val_accuracy: 0.9820 - val_loss: 0.0571
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 762ms/step - accuracy: 0.9890 - loss: 0.0270 - val_accuracy: 0.9830 - val_loss: 0.0562
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 547ms/step - accuracy: 0.9900 - loss: 0.0247 - val_accuracy: 0.9830 - val_loss: 0.0558
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 754ms/step - accuracy: 0.9880 - loss: 0.0333 - val_accuracy: 0.9830 - val_loss: 0.0555
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 756ms/step - accuracy: 0.9910 - loss: 0.0278 - val_accuracy: 0.9820 - val_loss: 0.0554
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 513ms/step - accuracy: 0.9885 - loss: 0.0303 - val_accuracy: 0.9820 - val_loss: 0.0551
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 470ms/step - accuracy: 0.9915 - loss: 0.0249 - val_accuracy: 0.9820 - val_loss: 0.0545
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 494ms/step - accuracy: 0.9900 - loss: 0.0217 - val_accuracy: 0.9820 - val_loss: 0.0544
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 493ms/step - accuracy: 0.9895 - loss: 0.0257 - val_accuracy: 0.9820 - val_loss: 0.0540
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 747ms/step - accuracy: 0.9900 - loss: 0.0239 - val_accuracy: 0.9820 - val_loss: 0.0535
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 712ms/step - accuracy: 0.9940 - loss: 0.0194 - val_accuracy: 0.9820 - val_loss: 0.0536
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 751ms/step - accuracy: 0.9925 - loss: 0.0224 - val_accuracy: 0.9810 - val_loss: 0.0534
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 729ms/step - accuracy: 0.9905 - loss: 0.0326 - val_accuracy: 0.9820 - val_loss: 0.0537
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 766ms/step - accuracy: 0.9925 - loss: 0.0206 - val_accuracy: 0.9810 - val_loss: 0.0531
# Epoch 19/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 532ms/step - accuracy: 0.9915 - loss: 0.0261 - val_accuracy: 0.9820 - val_loss: 0.0528
# Epoch 20/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 757ms/step - accuracy: 0.9975 - loss: 0.0162 - val_accuracy: 0.9820 - val_loss: 0.0526
# Epoch 21/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 499ms/step - accuracy: 0.9920 - loss: 0.0224 - val_accuracy: 0.9810 - val_loss: 0.0526
# Epoch 22/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 762ms/step - accuracy: 0.9910 - loss: 0.0246 - val_accuracy: 0.9830 - val_loss: 0.0517
# Epoch 23/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 759ms/step - accuracy: 0.9915 - loss: 0.0269 - val_accuracy: 0.9830 - val_loss: 0.0515
# Epoch 24/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 540ms/step - accuracy: 0.9875 - loss: 0.0319 - val_accuracy: 0.9840 - val_loss: 0.0516
# Epoch 25/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 729ms/step - accuracy: 0.9915 - loss: 0.0201 - val_accuracy: 0.9820 - val_loss: 0.0525
# Epoch 26/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 742ms/step - accuracy: 0.9930 - loss: 0.0208 - val_accuracy: 0.9820 - val_loss: 0.0520
# Epoch 27/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 735ms/step - accuracy: 0.9915 - loss: 0.0239 - val_accuracy: 0.9830 - val_loss: 0.0514
# Epoch 28/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 748ms/step - accuracy: 0.9915 - loss: 0.0251 - val_accuracy: 0.9840 - val_loss: 0.0513
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 761ms/step - accuracy: 0.9920 - loss: 0.0258 - val_accuracy: 0.9840 - val_loss: 0.0512
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 759ms/step - accuracy: 0.9900 - loss: 0.0328 - val_accuracy: 0.9840 - val_loss: 0.0509

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 301ms/step - accuracy: 0.9865 - loss: 0.0480
# Test accuracy: 0.987
