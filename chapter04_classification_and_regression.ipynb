# %% [markdown]
# <a href="https://colab.research.google.com/github/jc020230/2026-1-theory-practice/blob/main/chapter04_classification_and_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Third Edition](https://www.manning.com/books/deep-learning-with-python-third-edition). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# The book's contents are available online at [deeplearningwithpython.io](https://deeplearningwithpython.io).

# %%
# !pip install keras keras-hub --upgrade -q

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %% [markdown]
# ## Classification and regression

# %% [markdown]
# ### Classifying movie reviews: A binary classification example

# %% [markdown]
# #### The IMDb dataset

# %%
from keras.datasets import imdb

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(
    num_words=10000
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
train_data[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
train_labels[0]
# Out:
# np.int64(1)

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %%
word_index = imdb.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_review = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[0]]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 1s 1us/step

# %%
decoded_review[:100]
# Out:
# "? this film was just brilliant casting location scenery story direction everyone's really suited the"

# %% [markdown]
# #### Preparing the data

# %%
import numpy as np

def multi_hot_encode(sequences, num_classes):
    results = np.zeros((len(sequences), num_classes))
    for i, sequence in enumerate(sequences):
        results[i][sequence] = 1.0
    return results

x_train = multi_hot_encode(train_data, num_classes=10000)
x_test = multi_hot_encode(test_data, num_classes=10000)

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
y_train = train_labels.astype("float32")
y_test = test_labels.astype("float32")

# %% [markdown]
# #### Building your model

# %%
import keras
from keras import layers

model = keras.Sequential(
    [
        layers.Dense(16, activation="relu"),
        layers.Dense(16, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)

# %% [markdown]
# #### Validating your approach

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
history = model.fit(
    partial_x_train,
    partial_y_train,
    epochs=20,
    batch_size=512,
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - accuracy: 0.7577 - loss: 0.5707 - val_accuracy: 0.8433 - val_loss: 0.4273
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8919 - loss: 0.3162 - val_accuracy: 0.8859 - val_loss: 0.2972
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9308 - loss: 0.2059 - val_accuracy: 0.8900 - val_loss: 0.2764
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9521 - loss: 0.1488 - val_accuracy: 0.8862 - val_loss: 0.2828
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9666 - loss: 0.1123 - val_accuracy: 0.8832 - val_loss: 0.3062
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9752 - loss: 0.0880 - val_accuracy: 0.8810 - val_loss: 0.3277
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9845 - loss: 0.0654 - val_accuracy: 0.8791 - val_loss: 0.3547
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9911 - loss: 0.0489 - val_accuracy: 0.8769 - val_loss: 0.3831
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9941 - loss: 0.0372 - val_accuracy: 0.8760 - val_loss: 0.4170
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9967 - loss: 0.0295 - val_accuracy: 0.8745 - val_loss: 0.4468
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9986 - loss: 0.0220 - val_accuracy: 0.8685 - val_loss: 0.4765
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9994 - loss: 0.0172 - val_accuracy: 0.8700 - val_loss: 0.5005
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9997 - loss: 0.0133 - val_accuracy: 0.8691 - val_loss: 0.5263
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9998 - loss: 0.0108 - val_accuracy: 0.8670 - val_loss: 0.5516
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9999 - loss: 0.0088 - val_accuracy: 0.8669 - val_loss: 0.5728
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9999 - loss: 0.0072 - val_accuracy: 0.8668 - val_loss: 0.5938
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9999 - loss: 0.0061 - val_accuracy: 0.8661 - val_loss: 0.6129
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9999 - loss: 0.0052 - val_accuracy: 0.8662 - val_loss: 0.6306
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9999 - loss: 0.0045 - val_accuracy: 0.8658 - val_loss: 0.6473
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9999 - loss: 0.0039 - val_accuracy: 0.8663 - val_loss: 0.6628

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=512,
    validation_split=0.2,
)
# Out:
# Epoch 1/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9280 - loss: 0.2920 - val_accuracy: 0.9742 - val_loss: 0.0850
# Epoch 2/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9599 - loss: 0.1262 - val_accuracy: 0.9604 - val_loss: 0.1071
# Epoch 3/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9755 - loss: 0.0882 - val_accuracy: 0.9572 - val_loss: 0.1196
# Epoch 4/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9840 - loss: 0.0662 - val_accuracy: 0.9484 - val_loss: 0.1394
# Epoch 5/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9894 - loss: 0.0504 - val_accuracy: 0.9458 - val_loss: 0.1577
# Epoch 6/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9923 - loss: 0.0396 - val_accuracy: 0.9384 - val_loss: 0.1818
# Epoch 7/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9950 - loss: 0.0303 - val_accuracy: 0.9360 - val_loss: 0.2054
# Epoch 8/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0233 - val_accuracy: 0.9332 - val_loss: 0.2238
# Epoch 9/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9977 - loss: 0.0176 - val_accuracy: 0.9314 - val_loss: 0.2436
# Epoch 10/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9983 - loss: 0.0137 - val_accuracy: 0.9302 - val_loss: 0.2632
# Epoch 11/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9986 - loss: 0.0106 - val_accuracy: 0.9296 - val_loss: 0.2819
# Epoch 12/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9991 - loss: 0.0084 - val_accuracy: 0.9280 - val_loss: 0.2966
# Epoch 13/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9993 - loss: 0.0067 - val_accuracy: 0.9270 - val_loss: 0.3140
# Epoch 14/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9996 - loss: 0.0057 - val_accuracy: 0.9278 - val_loss: 0.3291
# Epoch 15/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9997 - loss: 0.0047 - val_accuracy: 0.9270 - val_loss: 0.3434
# Epoch 16/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9998 - loss: 0.0040 - val_accuracy: 0.9256 - val_loss: 0.3566
# Epoch 17/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9999 - loss: 0.0035 - val_accuracy: 0.9256 - val_loss: 0.3670
# Epoch 18/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9999 - loss: 0.0031 - val_accuracy: 0.9244 - val_loss: 0.3788
# Epoch 19/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9999 - loss: 0.0028 - val_accuracy: 0.9232 - val_loss: 0.3887
# Epoch 20/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9999 - loss: 0.0026 - val_accuracy: 0.9234 - val_loss: 0.3975

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "r--", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("[IMDB] Training and validation loss")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "r--", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("[IMDB] Training and validation accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        layers.Dense(16, activation="relu"),
        layers.Dense(16, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.7890 - loss: 0.4901
# Epoch 2/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9134 - loss: 0.2471
# Epoch 3/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9366 - loss: 0.1807
# Epoch 4/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9513 - loss: 0.1420
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8790 - loss: 0.3164

# %%
results
# Out:
# [0.31643280386924744, 0.8789999485015869]

# %% [markdown]
# #### Using a trained model to generate predictions on new data

# %%
model.predict(x_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# array([[0.18122828],
#        [0.99941653],
#        [0.7736928 ],
#        ...,
#        [0.10050549],
#        [0.07190567],
#        [0.7923548 ]], dtype=float32)

# %% [markdown]
# #### Further experiments

# %% [markdown]
# #### Wrapping up

# %% [markdown]
# ### Classifying newswires: A multiclass classification example

# %% [markdown]
# #### The Reuters dataset

# %%
from keras.datasets import reuters

(train_data, train_labels), (test_data, test_labels) = reuters.load_data(
    num_words=10000
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 ━━━━━━━━━━━━━━━━━━━━ 2s 1us/step

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %%
train_data[10]
# Out:
# [1,
#  245,
#  273,
#  207,
#  156,
#  53,
#  74,
#  160,
#  26,
#  14,
#  46,
#  296,
#  26,
#  39,
#  74,
#  2979,
#  3554,
#  14,
#  46,
#  4689,
#  4329,
#  86,
#  61,
#  3499,
#  4795,
#  14,
#  61,
#  451,
#  4329,
#  17,
#  12]

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[10]]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters_word_index.json
# 550378/550378 ━━━━━━━━━━━━━━━━━━━━ 1s 2us/step

# %%
train_labels[10]
# Out:
# np.int64(3)

# %% [markdown]
# #### Preparing the data

# %%
x_train = multi_hot_encode(train_data, num_classes=10000)
x_test = multi_hot_encode(test_data, num_classes=10000)

# %%
def one_hot_encode(labels, num_classes=46):
    results = np.zeros((len(labels), num_classes))
    for i, label in enumerate(labels):
        results[i, label] = 1.0
    return results

y_train = one_hot_encode(train_labels)
y_test = one_hot_encode(test_labels)

# %% [markdown]
# 왜 mnist에서는 0~9였는데, 여기서는 2개로 나누어 하지?

# %%
train_labels[:5]
# Out:
# array([3, 4, 3, 4, 4])

# %%
from keras.utils import to_categorical

y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)

# %% [markdown]
# #### Building your model

# %%
model = keras.Sequential(
    [
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(46, activation="softmax"),
    ]
)

# %%
top_3_accuracy = keras.metrics.TopKCategoricalAccuracy(
    k=3, name="top_3_accuracy"
)
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy", top_3_accuracy],
)

# %% [markdown]
# categorical entrophy로 해야 학습이 잘됨

# %% [markdown]
# #### Validating your approach

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = y_train[:1000]
partial_y_train = y_train[1000:]

# %%
history = model.fit(
    partial_x_train,
    partial_y_train,
    epochs=20,
    batch_size=512,
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.3765 - loss: 3.2545 - top_3_accuracy: 0.5529 - val_accuracy: 0.5270 - val_loss: 2.5019 - val_top_3_accuracy: 0.6860
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6092 - loss: 1.9719 - top_3_accuracy: 0.7398 - val_accuracy: 0.6580 - val_loss: 1.6065 - val_top_3_accuracy: 0.7710
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7191 - loss: 1.3351 - top_3_accuracy: 0.8128 - val_accuracy: 0.7180 - val_loss: 1.2837 - val_top_3_accuracy: 0.8150
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7796 - loss: 1.0217 - top_3_accuracy: 0.8649 - val_accuracy: 0.7630 - val_loss: 1.1263 - val_top_3_accuracy: 0.8600
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8326 - loss: 0.8130 - top_3_accuracy: 0.9067 - val_accuracy: 0.7960 - val_loss: 1.0242 - val_top_3_accuracy: 0.8880
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8643 - loss: 0.6472 - top_3_accuracy: 0.9360 - val_accuracy: 0.7980 - val_loss: 0.9688 - val_top_3_accuracy: 0.9020
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8924 - loss: 0.5173 - top_3_accuracy: 0.9583 - val_accuracy: 0.8120 - val_loss: 0.9262 - val_top_3_accuracy: 0.9090
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9143 - loss: 0.4110 - top_3_accuracy: 0.9743 - val_accuracy: 0.8130 - val_loss: 0.9003 - val_top_3_accuracy: 0.9140
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9296 - loss: 0.3297 - top_3_accuracy: 0.9841 - val_accuracy: 0.8200 - val_loss: 0.8878 - val_top_3_accuracy: 0.9160
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9417 - loss: 0.2678 - top_3_accuracy: 0.9895 - val_accuracy: 0.8150 - val_loss: 0.8920 - val_top_3_accuracy: 0.9190
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9496 - loss: 0.2225 - top_3_accuracy: 0.9930 - val_accuracy: 0.8160 - val_loss: 0.8960 - val_top_3_accuracy: 0.9270
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9523 - loss: 0.1906 - top_3_accuracy: 0.9944 - val_accuracy: 0.8200 - val_loss: 0.9176 - val_top_3_accuracy: 0.9190
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9546 - loss: 0.1684 - top_3_accuracy: 0.9957 - val_accuracy: 0.8120 - val_loss: 0.9256 - val_top_3_accuracy: 0.9230
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9575 - loss: 0.1493 - top_3_accuracy: 0.9974 - val_accuracy: 0.8190 - val_loss: 0.9324 - val_top_3_accuracy: 0.9220
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9583 - loss: 0.1404 - top_3_accuracy: 0.9980 - val_accuracy: 0.8020 - val_loss: 0.9520 - val_top_3_accuracy: 0.9210
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9612 - loss: 0.1258 - top_3_accuracy: 0.9982 - val_accuracy: 0.8020 - val_loss: 0.9557 - val_top_3_accuracy: 0.9240
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9610 - loss: 0.1209 - top_3_accuracy: 0.9987 - val_accuracy: 0.8100 - val_loss: 0.9734 - val_top_3_accuracy: 0.9240
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9580 - loss: 0.1133 - top_3_accuracy: 0.9989 - val_accuracy: 0.8070 - val_loss: 0.9801 - val_top_3_accuracy: 0.9240
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9603 - loss: 0.1063 - top_3_accuracy: 0.9987 - val_accuracy: 0.8100 - val_loss: 1.0125 - val_top_3_accuracy: 0.9200
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9622 - loss: 0.1071 - top_3_accuracy: 0.9992 - val_accuracy: 0.8090 - val_loss: 1.0040 - val_top_3_accuracy: 0.9200

# %%
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history.history["top_3_accuracy"]
val_acc = history.history["val_top_3_accuracy"]
plt.plot(epochs, acc, "r--", label="Training top-3 accuracy")
plt.plot(epochs, val_acc, "b", label="Validation top-3 accuracy")
plt.title("Training and validation top-3 accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Top-3 accuracy")
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(46, activation="softmax"),
    ]
)
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    x_train,
    y_train,
    epochs=9,
    batch_size=512,
)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.4536 - loss: 3.1939
# Epoch 2/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6221 - loss: 1.8840
# Epoch 3/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7216 - loss: 1.2725
# Epoch 4/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7945 - loss: 0.9673
# Epoch 5/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8430 - loss: 0.7518
# Epoch 6/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8811 - loss: 0.5833
# Epoch 7/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9085 - loss: 0.4522
# Epoch 8/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9271 - loss: 0.3552
# Epoch 9/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9410 - loss: 0.2803
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7979 - loss: 0.9257

# %%
results
# Out:
# [0.9257222414016724, 0.7978628873825073]

# %%
import copy
test_labels_copy = copy.copy(test_labels)
np.random.shuffle(test_labels_copy)
hits_array = np.array(test_labels == test_labels_copy)
hits_array.mean()
# Out:
# np.float64(0.1861086375779163)

# %% [markdown]
# #### Generating predictions on new data

# %%
predictions = model.predict(x_test)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
predictions[0].shape
# Out:
# (46,)

# %%
np.sum(predictions[0])
# Out:
# np.float32(1.0000001)

# %%
np.argmax(predictions[0])
# Out:
# np.int64(3)

# %% [markdown]
# #### A different way to handle the labels and the loss

# %%
y_train = train_labels
y_test = test_labels

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %% [markdown]
# #### The importance of having sufficiently large intermediate layers

# %%
model = keras.Sequential(
    [
        layers.Dense(64, activation="relu"),
        layers.Dense(4, activation="relu"),
        layers.Dense(46, activation="softmax"),
    ]
)
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    partial_x_train,
    partial_y_train,
    epochs=20,
    batch_size=128,
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.4518 - loss: 3.0054 - val_accuracy: 0.5780 - val_loss: 2.0225
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6232 - loss: 1.6122 - val_accuracy: 0.6230 - val_loss: 1.5303
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6849 - loss: 1.2819 - val_accuracy: 0.6690 - val_loss: 1.4169
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7275 - loss: 1.1094 - val_accuracy: 0.6770 - val_loss: 1.3560
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7399 - loss: 0.9929 - val_accuracy: 0.6790 - val_loss: 1.3423
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7491 - loss: 0.9068 - val_accuracy: 0.6770 - val_loss: 1.3221
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7645 - loss: 0.8332 - val_accuracy: 0.6960 - val_loss: 1.3160
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7905 - loss: 0.7731 - val_accuracy: 0.7020 - val_loss: 1.3284
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8052 - loss: 0.7180 - val_accuracy: 0.7050 - val_loss: 1.3210
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8161 - loss: 0.6709 - val_accuracy: 0.7050 - val_loss: 1.3647
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8231 - loss: 0.6301 - val_accuracy: 0.7080 - val_loss: 1.3748
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8344 - loss: 0.5979 - val_accuracy: 0.7170 - val_loss: 1.3843
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8426 - loss: 0.5699 - val_accuracy: 0.7240 - val_loss: 1.4077
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8497 - loss: 0.5467 - val_accuracy: 0.7180 - val_loss: 1.4298
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8504 - loss: 0.5253 - val_accuracy: 0.7140 - val_loss: 1.4446
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8533 - loss: 0.5080 - val_accuracy: 0.7160 - val_loss: 1.4795
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8582 - loss: 0.4916 - val_accuracy: 0.7130 - val_loss: 1.4977
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8611 - loss: 0.4785 - val_accuracy: 0.7130 - val_loss: 1.5091
# Epoch 19/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8637 - loss: 0.4621 - val_accuracy: 0.7110 - val_loss: 1.5322
# Epoch 20/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8675 - loss: 0.4495 - val_accuracy: 0.7120 - val_loss: 1.6198

# %% [markdown]
# #### Further experiments

# %% [markdown]
# #### Wrapping up

# %% [markdown]
# ### Predicting house prices: A regression example

# %% [markdown]
# #### The California Housing Price dataset

# %%
from keras.datasets import california_housing

(train_data, train_targets), (test_data, test_targets) = (
    california_housing.load_data(version="small")
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/california_housing.npz
# 743530/743530 ━━━━━━━━━━━━━━━━━━━━ 1s 2us/step

# %%
train_data.shape
# Out:
# (480, 8)

# %%
test_data.shape
# Out:
# (120, 8)

# %%
train_targets
# Out:
# array([228400., 132900.,  60000.,  95200., 107000., 122500., 132000.,
#        290100., 257800., 390100., 220800., 284900.,  97500., 415300.,
#         84200., 185600., 216700., 233100., 127000., 182300.,  92300.,
#         90700., 102100., 112500., 350700., 156500., 220700., 147400.,
#        216700., 275000., 198200., 119100., 289500., 152500., 125000.,
#        104500.,  93800.,  89300., 452600., 128600., 311500.,  90000.,
#        218200., 131300.,  67500., 139400., 500001., 182600., 111300.,
#        112500., 134700.,  71300., 207400., 331400., 107900.,  87500.,
#        342200.,  87100., 314700., 368600., 211600., 338900., 366100.,
#        164300.,  91700., 261400., 218500., 155400., 273700.,  81800.,
#        138800.,  99700., 156300., 140600., 152700., 108900., 351200.,
#        126000., 137500., 196900., 240000., 172800., 254200.,  97500.,
#        182700., 162500.,  86100., 226700., 412500., 165900., 327100.,
#        162500., 188800., 183800.,  90600., 372000., 275000., 151800.,
#        125000., 129100., 176000., 124700., 215300., 198100., 206300.,
#        122300., 277800., 335200., 274700., 132600., 143900., 299200.,
#        160000., 210200., 171400., 138800., 203300., 143800.,  85800.,
#         75000., 112200., 340400., 105500., 208100., 270900.,  85700.,
#         81300., 352100., 285800., 270600., 216700., 270100., 374400.,
#        192100., 241700., 341300., 150000., 126300., 118800., 500001.,
#         95200., 173700., 175000., 113900., 335000., 100000., 235600.,
#        109700., 210200.,  81400., 286600., 201300., 142300., 102300.,
#        184400.,  98300., 295200., 247100., 107500., 104900.,  79700.,
#        112500., 318200.,  83400., 269500., 227900., 287500., 261100.,
#        166900., 144000., 245500., 101600., 471600., 240700., 137500.,
#         75000.,  80800., 257300., 162900., 292000., 323500., 126900.,
#        351800., 269700., 212900., 259600., 268500., 182300., 197900.,
#        213500., 107600., 231600., 335300., 257400., 100000., 206200.,
#        119400., 118100.,  92500., 158700., 289900., 101400., 125000.,
#         91400., 500001., 500001., 275700., 457800., 239800., 250000.,
#        191700., 130000., 156900., 118800.,  88800., 153100., 231000.,
#        430500., 333300., 141900., 140000., 209400., 270900., 225000.,
#        229100., 150000., 164700.,  82800., 135800., 116700., 405400.,
#        231600.,  89500., 276800., 248600., 195800.,  98200., 319300.,
#        241700., 229800., 306300., 118000., 227700., 128800., 344000.,
#        120000., 110400., 335600., 109400., 161900., 135300., 142500.,
#        347600., 391800.,  82400., 332500., 336800., 109500., 391100.,
#         84700., 252900., 200000., 164300., 187500., 392600., 417500.,
#        263400., 313400., 115400.,  76100., 253600., 265400., 218800.,
#        116100., 169300., 114800., 358800., 302100., 143800., 446200.,
#        456300., 293000., 142600., 137500., 157300., 229300., 102200.,
#        169900., 243100.,  86500., 111100., 246200., 208800., 248500.,
#        295200., 500001., 164400., 365900., 296400., 376900., 242800.,
#         91800., 129500., 130600., 220900., 250000., 263900.,  72500.,
#        234100., 144800., 150000.,  70000.,  90500., 105500., 218400.,
#        282100., 147500., 224200., 120100., 104200.,  97200., 112500.,
#         94800., 273000., 159800., 225000.,  96200., 327600., 111900.,
#        266700., 333000., 375400., 350000., 103900., 243800.,  87100.,
#        141700., 366700.,  80000., 174200., 106300., 102000.,  88900.,
#        348700., 132500., 272900., 292300., 231800., 162500., 187500.,
#        352400., 384600., 153600., 240900., 500001., 189600., 151000.,
#        163500., 229200.,  98700., 138800., 136700., 398600., 254900.,
#        137000., 146900., 371300., 220800., 346800., 341600., 199600.,
#        140600., 342200., 137500., 411500., 125000.,  72000.,  83500.,
#        357300., 187500., 410300., 112500., 273800., 179300., 143400.,
#        121600., 177500., 252800., 287500., 271400., 121400., 131900.,
#        329800.,  85000., 127900., 155500., 172700., 113300., 125000.,
#        252500., 102400., 136700., 221300., 191400.,  82000., 218500.,
#        227000., 144800., 500001., 232500., 243400., 259400., 137500.,
#        337300., 179200., 102800., 207900., 362900., 350000.,  73500.,
#        371100., 182700., 389500., 140600.,  87500., 142900., 196400.,
#        126600., 123500., 311100., 159200.,  95000.,  81800., 253500.,
#        215700., 171900.,  85300.,  80600.,  89300.,  84400.,  75000.,
#        228100.,  95500., 187100.,  94800., 224100., 239600., 115000.,
#        353900., 256100., 335700., 291700., 206300., 119400., 350000.,
#        287300., 191300.,  93800., 175000., 500001., 179300., 118800.,
#        206800., 179900.,  80300., 195500., 147900., 483300., 268800.,
#        158400.,  94300.,  97300., 275400., 248900., 273400., 259300.,
#         75700., 336700., 140500., 217100.], dtype=float32)

# %% [markdown]
# #### Preparing the data

# %%
mean = train_data.mean(axis=0)
std = train_data.std(axis=0)
x_train = (train_data - mean) / std
x_test = (test_data - mean) / std

# %%
y_train = train_targets / 100000
y_test = test_targets / 100000

# %% [markdown]
# #### Building your model

# %%
def get_model():
    model = keras.Sequential(
        [
            layers.Dense(64, activation="relu"),
            layers.Dense(64, activation="relu"),
            layers.Dense(1),
        ]
    )
    model.compile(
        optimizer="adam",
        loss="mean_squared_error",
        metrics=["mean_absolute_error"],
    )
    return model

# %% [markdown]
# #### Validating your approach using K-fold validation

# %%
k = 4
num_val_samples = len(x_train) // k
num_epochs = 50
all_scores = []
for i in range(k):
    print(f"Processing fold #{i + 1}")
    fold_x_val = x_train[i * num_val_samples : (i + 1) * num_val_samples]
    fold_y_val = y_train[i * num_val_samples : (i + 1) * num_val_samples]
    fold_x_train = np.concatenate(
        [x_train[: i * num_val_samples], x_train[(i + 1) * num_val_samples :]],
        axis=0,
    )
    fold_y_train = np.concatenate(
        [y_train[: i * num_val_samples], y_train[(i + 1) * num_val_samples :]],
        axis=0,
    )
    model = get_model()
    model.fit(
        fold_x_train,
        fold_y_train,
        epochs=num_epochs,
        batch_size=16,
        verbose=0,
    )
    scores = model.evaluate(fold_x_val, fold_y_val, verbose=0)
    val_loss, val_mae = scores
    all_scores.append(val_mae)
# Out:
# Processing fold #1
# Processing fold #2
# Processing fold #3
# Processing fold #4

# %%
[round(value, 3) for value in all_scores]
# Out:
# [0.303, 0.293, 0.254, 0.32]

# %%
round(np.mean(all_scores), 3)
# Out:
# np.float64(0.293)

# %%
k = 4
num_val_samples = len(x_train) // k
num_epochs = 200
all_mae_histories = []
for i in range(k):
    print(f"Processing fold #{i + 1}")
    fold_x_val = x_train[i * num_val_samples : (i + 1) * num_val_samples]
    fold_y_val = y_train[i * num_val_samples : (i + 1) * num_val_samples]
    fold_x_train = np.concatenate(
        [x_train[: i * num_val_samples], x_train[(i + 1) * num_val_samples :]],
        axis=0,
    )
    fold_y_train = np.concatenate(
        [y_train[: i * num_val_samples], y_train[(i + 1) * num_val_samples :]],
        axis=0,
    )
    model = get_model()
    history = model.fit(
        fold_x_train,
        fold_y_train,
        validation_data=(fold_x_val, fold_y_val),
        epochs=num_epochs,
        batch_size=16,
        verbose=0,
    )
    mae_history = history.history["val_mean_absolute_error"]
    all_mae_histories.append(mae_history)
# Out:
# Processing fold #1
# Processing fold #2
# Processing fold #3
# Processing fold #4

# %%
average_mae_history = [
    np.mean([x[i] for x in all_mae_histories]) for i in range(num_epochs)
]

# %%
epochs = range(1, len(average_mae_history) + 1)
plt.plot(epochs, average_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
plt.show()

# %%
truncated_mae_history = average_mae_history[10:]
epochs = range(10, len(truncated_mae_history) + 10)
plt.plot(epochs, truncated_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
plt.show()

# %%
model = get_model()
model.fit(x_train, y_train, epochs=130, batch_size=16, verbose=0)
test_mean_squared_error, test_mean_absolute_error = model.evaluate(
    x_test, y_test
)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.3296 - mean_absolute_error: 0.3187

# %%
round(test_mean_absolute_error, 3)
# Out:
# 0.319

# %% [markdown]
# #### Generating predictions on new data

# %%
predictions = model.predict(x_test)
predictions[0]
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# array([2.6725852], dtype=float32)

# %% [markdown]
# #### Wrapping up
